# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
file_path="Resources/Electric_Vehicle_Charging_Stations_in_New_York.csv"
Charger_df=pd.read_csv(file_path)
Charger_df
# Out:
#      Fuel Type Code                Station Name                Street Address  \
# 0              ELEC  Town of Penfield - Library                 1985 Baird Rd
# 1              ELEC          Village of Webster           28 West Main Street
# 2              ELEC   HOTSARA CHARGER STATION 1                   100 Main St
# 3              ELEC            Houghton College                    9736 Rt 19
# 4              ELEC    NYC FLEET DPRMBLOT8_1_L3     920 Father Capodanno Blvd
# ...             ...                         ...                           ...
# 3079           ELEC       W DELAVAN DELAVAN (1)             722 W Delavan Ave
# 3080           ELEC       HAMPTON INN STATION 1                1120 South Ave
# 3081           ELEC    SRYMCASSB BATTENKILL 1.1               15 Van Ness Ave
# 3082           ELEC  PAUL MILLER VW VW_408107_A           5865 Rome-Taberg Rd
# 3083           ELEC        GENESEO E PARK RIGHT  4319 Genesee Valley Plaza Rd
#
#      Intersection Directions           City State    ZIP  Plus4 Station Phone  \
# 0                        NaN       Penfield    NY  14526    NaN  585-340-8720
# 1                        NaN        Webster    NY  14580    NaN  866-816-7584
# 2                        NaN   Saranac Lake    NY  12983    NaN  888-758-4389
# 3                        NaN       Houghton    NY  14744    NaN  866-816-7584
# 4                        NaN  Midland Beach    NY  10305    NaN  888-758-4389
# ...                      ...            ...   ...    ...    ...           ...
# 3079                     NaN        Buffalo    NY  14222    NaN  888-758-4389
# 3080                     NaN  Staten Island    NY  10314    NaN  888-758-4389
# 3081                     NaN      Greenwich    NY  12834    NaN  888-758-4389
# 3082                     NaN           Rome    NY  13440    NaN  888-758-4389
# 3083                     NaN        Geneseo    NY  14454    NaN  888-758-4389
#
#      Status Code  ...   Latitude  Longitude Date Last Confirmed      ID  \
# 0              E  ...  43.137476 -77.465214          06/07/2021   49941
# 1              E  ...  43.211386 -77.431663          11/10/2022  116756
# 2              E  ...  44.326862 -74.130150          11/10/2022  149787
# 3              E  ...  42.423869 -78.154428          11/10/2022  157942
# 4              E  ...  40.572636 -74.086140          11/10/2022  182295
# ...          ...  ...        ...        ...                 ...     ...
# 3079           E  ...  42.922743 -78.873098          11/10/2022  154370
# 3080           E  ...  40.612696 -74.179012          11/10/2022  168146
# 3081           E  ...  43.093964 -73.506775          11/10/2022  183460
# 3082           E  ...  43.233239 -75.497597          11/10/2022  152393
# 3083           E  ...  42.798031 -77.783211          11/10/2022  224227
#
#                Updated At  Owner Type Code  Federal Agency ID  \
# 0     2022-02-10 19:42:29               LG                NaN
# 1     2022-11-10 02:00:34              NaN                NaN
# 2     2022-11-10 00:57:46              NaN                NaN
# 3     2022-11-10 02:00:45              NaN                NaN
# 4     2022-11-10 01:05:12              NaN                NaN
# ...                   ...              ...                ...
# 3079  2022-11-10 01:01:48              NaN                NaN
# 3080  2022-11-10 01:05:20              NaN                NaN
# 3081  2022-11-10 01:06:06              NaN                NaN
# 3082  2022-11-10 00:42:37              NaN                NaN
# 3083  2022-11-10 01:15:40              NaN                NaN
#
#      Federal Agency Name   Open Date  EV Connector Types
# 0                    NaN  04/01/2012               J1772
# 1                    NaN  08/31/2018               J1772
# 2                    NaN  12/07/2019               J1772
# 3                    NaN  05/15/2020               J1772
# 4                    NaN  01/27/2021  CHADEMO J1772COMBO
# ...                  ...         ...                 ...
# 3079                 NaN  03/07/2020               J1772
# 3080                 NaN  11/05/2020               J1772
# 3081                 NaN  01/27/2021               J1772
# 3082                 NaN  01/11/2020               J1772
# 3083                 NaN  07/22/2022               J1772
#
# [3084 rows x 31 columns]

# %%
Charger_df.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address',
#        'Intersection Directions', 'City', 'State', 'ZIP', 'Plus4',
#        'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'EV Level1 EVSE Num', 'EV Level2 EVSE Num', 'EV DC Fast Count',
#        'EV Other Info', 'EV Network', 'EV Network Web', 'Geocode Status',
#        'Latitude', 'Longitude', 'Date Last Confirmed', 'ID', 'Updated At',
#        'Owner Type Code', 'Federal Agency ID', 'Federal Agency Name',
#        'Open Date', 'EV Connector Types'],
#       dtype='object')

# %%
Charger_df = Charger_df [['ID','Station Name', 'City', 'ZIP']]
Charger_df
# Out:
#           ID                Station Name           City    ZIP
# 0      49941  Town of Penfield - Library       Penfield  14526
# 1     116756          Village of Webster        Webster  14580
# 2     149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983
# 3     157942            Houghton College       Houghton  14744
# 4     182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305
# ...      ...                         ...            ...    ...
# 3079  154370       W DELAVAN DELAVAN (1)        Buffalo  14222
# 3080  168146       HAMPTON INN STATION 1  Staten Island  10314
# 3081  183460    SRYMCASSB BATTENKILL 1.1      Greenwich  12834
# 3082  152393  PAUL MILLER VW VW_408107_A           Rome  13440
# 3083  224227        GENESEO E PARK RIGHT        Geneseo  14454
#
# [3084 rows x 4 columns]

# %%
Charger_df['City'].nunique()
# Out:
# 570

# %%
from uszipcode import SearchEngine
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Creating a dictionary that shows which county each zipcode is in
zipcodes_to_search = list(Charger_df['ZIP'].unique())
search = SearchEngine()
zip_map = {}

# excluding the zipcode not corresponded to any county
for zipcode in zipcodes_to_search:
    if zipcode == 12081:
        pass
    elif zipcode == 12217:
        pass
    else:
        zip_info = search.by_zipcode(zipcode).county
        zip_map[zipcode] = zip_info

zip_map
# Out:
# {14526: 'Monroe County',
#  14580: 'Monroe County',
#  12983: 'Franklin County',
#  14744: 'Allegany County',
#  10305: 'Richmond County',
#  14227: 'Erie County',
#  11220: 'Kings County',
#  13090: 'Onondaga County',
#  10954: 'Rockland County',
#  14853: 'Tompkins County',
#  11040: 'Nassau County',
#  12205: 'Albany County',
#  11976: 'Suffolk County',
#  12590: 'Dutchess County',
#  11212: 'Kings County',
#  12534: 'Columbia County',
#  14204: 'Erie County',
#  10901: 'Rockland County',
#  12180: 'Rensselaer County',
#  10065: 'New York County',
#  13027: 'Onondaga County',
#  14621: 'Monroe County',
#  11954: 'Suffolk County',
#  11710: 'Nassau County',
#  12110: 'Albany County',
#  11901: 'Suffolk County',
#  12020: 'Saratoga County',
#  12477: 'Ulster County',
#  13441: 'Oneida County',
#  12144: 'Rensselaer County',
#  14223: 'Erie County',
#  14850: 'Tompkins County',
#  14616: 'Monroe County',
#  12054: 'Albany County',
#  12866: 'Saratoga County',
#  14731: 'Cattaraugus County',
#  10022: 'New York County',
#  14072: 'Erie County',
#  12065: 'Saratoga County',
#  11766: 'Suffolk County',
#  13326: 'Otsego County',
#  12561: 'Ulster County',
#  11705: 'Suffolk County',
#  12203: 'Albany County',
#  10025: 'New York County',
#  11415: 'Queens County',
#  12204: 'Albany County',
#  14210: 'Erie County',
#  10314: 'Richmond County',
#  10028: 'New York County',
#  10523: 'Westchester County',
#  10013: 'New York County',
#  14830: 'Steuben County',
#  12202: 'Albany County',
#  11732: 'Nassau County',
#  12211: 'Albany County',
#  10069: 'New York County',
#  14564: 'Ontario County',
#  10573: 'Westchester County',
#  10033: 'New York County',
#  13413: 'Oneida County',
#  12817: 'Warren County',
#  14623: 'Monroe County',
#  12970: 'Franklin County',
#  14617: 'Monroe County',
#  12569: 'Dutchess County',
#  14612: 'Monroe County',
#  13365: 'Herkimer County',
#  10016: 'New York County',
#  11570: 'Nassau County',
#  13473: 'Lewis County',
#  11967: 'Suffolk County',
#  14450: 'Monroe County',
#  14472: 'Monroe County',
#  10280: 'New York County',
#  13077: 'Cortland County',
#  10301: 'Richmond County',
#  14760: 'Cattaraugus County',
#  14221: 'Erie County',
#  12853: 'Warren County',
#  10075: 'New York County',
#  12946: 'Essex County',
#  11520: 'Nassau County',
#  13032: 'Madison County',
#  14845: 'Chemung County',
#  12522: 'Dutchess County',
#  14626: 'Monroe County',
#  14203: 'Erie County',
#  10007: 'New York County',
#  12525: 'Ulster County',
#  11203: 'Kings County',
#  14604: 'Monroe County',
#  13202: 'Onondaga County',
#  10570: 'Westchester County',
#  11569: 'Nassau County',
#  14216: 'Erie County',
#  11232: 'Kings County',
#  11372: 'Queens County',
#  10036: 'New York County',
#  12009: 'Albany County',
#  13080: 'Onondaga County',
#  12953: 'Franklin County',
#  12189: 'Albany County',
#  12303: 'Schenectady County',
#  12095: 'Fulton County',
#  12545: 'Dutchess County',
#  14865: 'Schuyler County',
#  10911: 'Orange County',
#  12305: 'Schenectady County',
#  14211: 'Erie County',
#  14487: 'Livingston County',
#  13320: 'Otsego County',
#  10924: 'Orange County',
#  10976: 'Rockland County',
#  11433: 'Queens County',
#  10956: 'Rockland County',
#  14048: 'Chautauqua County',
#  10466: 'Bronx County',
#  11219: 'Kings County',
#  13021: 'Cayuga County',
#  14606: 'Monroe County',
#  10021: 'New York County',
#  14225: 'Erie County',
#  10023: 'New York County',
#  13126: 'Oswego County',
#  12901: 'Clinton County',
#  11215: 'Kings County',
#  12601: 'Dutchess County',
#  14063: 'Chautauqua County',
#  11201: 'Kings County',
#  13655: 'St. Lawrence County',
#  10044: 'New York County',
#  13203: 'Onondaga County',
#  11793: 'Nassau County',
#  12308: 'Schenectady County',
#  12804: 'Warren County',
#  12526: 'Columbia County',
#  12134: 'Fulton County',
#  13210: 'Onondaga County',
#  13495: 'Oneida County',
#  10463: 'Bronx County',
#  12493: 'Ulster County',
#  10306: 'Richmond County',
#  11590: 'Nassau County',
#  12209: 'Albany County',
#  11096: 'Nassau County',
#  10926: 'Orange County',
#  10562: 'Westchester County',
#  10002: 'New York County',
#  10475: 'Bronx County',
#  14607: 'Monroe County',
#  12771: 'Orange County',
#  13601: 'Jefferson County',
#  13502: 'Oneida County',
#  12504: 'Dutchess County',
#  11217: 'Kings County',
#  11933: 'Suffolk County',
#  13244: 'Onondaga County',
#  12801: 'Warren County',
#  11729: 'Suffolk County',
#  12047: 'Albany County',
#  12548: 'Ulster County',
#  12547: 'Ulster County',
#  12550: 'Orange County',
#  12302: 'Schenectady County',
#  10281: 'New York County',
#  14127: 'Erie County',
#  11758: 'Nassau County',
#  10001: 'New York County',
#  14624: 'Monroe County',
#  13045: 'Cortland County',
#  10019: 'New York County',
#  11206: 'Kings County',
#  14226: 'Erie County',
#  10940: 'Orange County',
#  12208: 'Albany County',
#  12401: 'Ulster County',
#  12207: 'Albany County',
#  10017: 'New York County',
#  12529: 'Columbia County',
#  14701: 'Chautauqua County',
#  13066: 'Onondaga County',
#  11231: 'Kings County',
#  11101: 'Queens County',
#  14411: 'Orleans County',
#  11934: 'Suffolk County',
#  11222: 'Kings County',
#  13827: 'Tioga County',
#  12571: 'Dutchess County',
#  14136: 'Chautauqua County',
#  13206: 'Onondaga County',
#  10011: 'New York County',
#  10601: 'Westchester County',
#  10567: 'Westchester County',
#  11738: 'Suffolk County',
#  12997: 'Essex County',
#  12019: 'Saratoga County',
#  14220: 'Erie County',
#  11109: 'Queens County',
#  10606: 'Westchester County',
#  13905: 'Broome County',
#  12845: 'Warren County',
#  14228: 'Erie County',
#  14445: 'Monroe County',
#  11968: 'Suffolk County',
#  14006: 'Erie County',
#  11803: 'Nassau County',
#  14886: 'Tompkins County',
#  11379: 'Queens County',
#  13322: 'Oneida County',
#  11937: 'Suffolk County',
#  12485: 'Greene County',
#  10591: 'Westchester County',
#  14206: 'Erie County',
#  14202: 'Erie County',
#  12010: 'Montgomery County',
#  13617: 'St. Lawrence County',
#  10707: 'Westchester County',
#  10960: 'Rockland County',
#  14750: 'Chautauqua County',
#  11790: 'Suffolk County',
#  11211: 'Kings County',
#  11530: 'Nassau County',
#  10012: 'New York County',
#  10471: 'Bronx County',
#  14424: 'Ontario County',
#  11371: 'Queens County',
#  11755: 'Suffolk County',
#  14502: 'Wayne County',
#  11735: 'Nassau County',
#  11377: 'Queens County',
#  10801: 'Westchester County',
#  10580: 'Westchester County',
#  13367: 'Lewis County',
#  13812: 'Tioga County',
#  14456: 'Ontario County',
#  12198: 'Rensselaer County',
#  12451: 'Greene County',
#  10538: 'Westchester County',
#  13904: 'Broome County',
#  12603: 'Dutchess County',
#  12304: 'Schenectady County',
#  13323: 'Oneida County',
#  10533: 'Westchester County',
#  13850: 'Broome County',
#  12210: 'Albany County',
#  14209: 'Erie County',
#  14139: 'Erie County',
#  10708: 'Westchester County',
#  11964: 'Suffolk County',
#  12936: 'Essex County',
#  12061: 'Rensselaer County',
#  12701: 'Sullivan County',
#  12422: 'Greene County',
#  13368: 'Lewis County',
#  14837: 'Yates County',
#  12309: 'Schenectady County',
#  12508: 'Dutchess County',
#  14214: 'Erie County',
#  13165: 'Seneca County',
#  12828: 'Washington County',
#  10803: 'Westchester County',
#  10552: 'Westchester County',
#  10030: 'New York County',
#  12528: 'Ulster County',
#  10802: 'Westchester County',
#  10034: 'New York County',
#  14615: 'Monroe County',
#  11777: 'Suffolk County',
#  11963: 'Suffolk County',
#  13152: 'Onondaga County',
#  14092: 'Niagara County',
#  13662: 'St. Lawrence County',
#  14905: 'Chemung County',
#  13308: 'Oneida County',
#  10507: 'Westchester County',
#  10004: 'New York County',
#  11961: 'Suffolk County',
#  14810: 'Steuben County',
#  12414: 'Greene County',
#  14222: 'Erie County',
#  11701: 'Suffolk County',
#  13057: 'Onondaga County',
#  11947: 'Suffolk County',
#  12166: 'Montgomery County',
#  12803: 'Saratoga County',
#  12759: 'Sullivan County',
#  13820: 'Otsego County',
#  10710: 'Westchester County',
#  10604: 'Westchester County',
#  11368: 'Queens County',
#  10913: 'Rockland County',
#  14131: 'Niagara County',
#  14903: 'Chemung County',
#  11771: 'Nassau County',
#  14818: 'Schuyler County',
#  14870: 'Steuben County',
#  11772: 'Suffolk County',
#  13901: 'Broome County',
#  10035: 'New York County',
#  10605: 'Westchester County',
#  10530: 'Westchester County',
#  10282: 'New York County',
#  11354: 'Queens County',
#  11706: 'Suffolk County',
#  10003: 'New York County',
#  10014: 'New York County',
#  10917: 'Orange County',
#  12159: 'Albany County',
#  14513: 'Wayne County',
#  11788: 'Suffolk County',
#  14103: 'Orleans County',
#  14618: 'Monroe County',
#  14620: 'Monroe County',
#  12514: 'Dutchess County',
#  14420: 'Monroe County',
#  12540: 'Dutchess County',
#  13346: 'Madison County',
#  12572: 'Dutchess County',
#  13731: 'Delaware County',
#  14611: 'Monroe County',
#  10524: 'Putnam County',
#  11249: 'Kings County',
#  12077: 'Albany County',
#  12498: 'Ulster County',
#  10010: 'New York County',
#  11776: 'Suffolk County',
#  11720: 'Suffolk County',
#  13026: 'Cayuga County',
#  10024: 'New York County',
#  10701: 'Westchester County',
#  14020: 'Genesee County',
#  14559: 'Monroe County',
#  11238: 'Kings County',
#  12604: 'Dutchess County',
#  11746: 'Suffolk County',
#  11355: 'Queens County',
#  14414: 'Livingston County',
#  11801: 'Nassau County',
#  12015: 'Greene County',
#  11743: 'Suffolk County',
#  12993: 'Essex County',
#  10595: 'Westchester County',
#  12992: 'Clinton County',
#  14454: 'Livingston County',
#  10080: 'New York County',
#  11514: 'Nassau County',
#  14627: 'Monroe County',
#  14546: 'Monroe County',
#  11703: 'Suffolk County',
#  12513: 'Columbia County',
#  11554: 'Nassau County',
#  12446: 'Ulster County',
#  12206: 'Albany County',
#  13030: 'Madison County',
#  10965: 'Rockland County',
#  14428: 'Monroe County',
#  11369: 'Queens County',
#  12084: 'Albany County',
#  11423: 'Queens County',
#  11106: 'Queens County',
#  13064: 'Cayuga County',
#  14864: 'Chemung County',
#  11375: 'Queens County',
#  13036: 'Oswego County',
#  12118: 'Saratoga County',
#  14779: 'Cattaraugus County',
#  10026: 'New York County',
#  11432: 'Queens County',
#  12164: 'Hamilton County',
#  11577: 'Nassau County',
#  11367: 'Queens County',
#  11724: 'Suffolk County',
#  10520: 'Westchester County',
#  12538: 'Dutchess County',
#  12496: 'Greene County',
#  13340: 'Herkimer County',
#  11747: 'Suffolk County',
#  13212: 'Onondaga County',
#  12986: 'Franklin County',
#  14813: 'Allegany County',
#  13088: 'Onondaga County',
#  13753: 'Delaware County',
#  14031: 'Erie County',
#  10309: 'Richmond County',
#  10928: 'Orange County',
#  13360: 'Hamilton County',
#  12033: 'Rensselaer County',
#  12852: 'Essex County',
#  11725: 'Suffolk County',
#  14432: 'Ontario County',
#  11205: 'Kings County',
#  14086: 'Erie County',
#  11767: 'Suffolk County',
#  12143: 'Albany County',
#  14609: 'Monroe County',
#  14418: 'Yates County',
#  11435: 'Queens County',
#  14150: 'Erie County',
#  12594: 'Dutchess County',
#  11949: 'Suffolk County',
#  10804: 'Westchester County',
#  10958: 'Orange County',
#  10027: 'New York County',
#  12831: 'Saratoga County',
#  10514: 'Westchester County',
#  14551: 'Wayne County',
#  14891: 'Schuyler County',
#  12974: 'Essex County',
#  11694: 'Queens County',
#  10994: 'Rockland County',
#  14305: 'Niagara County',
#  12306: 'Schenectady County',
#  11103: 'Queens County',
#  14719: 'Cattaraugus County',
#  11230: 'Kings County',
#  12087: 'Greene County',
#  11714: 'Nassau County',
#  14120: 'Niagara County',
#  14787: 'Chautauqua County',
#  10128: 'New York County',
#  14304: 'Niagara County',
#  13478: 'Oneida County',
#  12564: 'Dutchess County',
#  12182: 'Rensselaer County',
#  12037: 'Columbia County',
#  10155: 'New York County',
#  13760: 'Broome County',
#  12928: 'Essex County',
#  12484: 'Ulster County',
#  12814: 'Warren County',
#  14141: 'Erie County',
#  13053: 'Tompkins County',
#  14757: 'Chautauqua County',
#  10706: 'Westchester County',
#  10467: 'Bronx County',
#  11542: 'Nassau County',
#  10310: 'Richmond County',
#  14586: 'Monroe County',
#  12053: 'Schenectady County',
#  13676: 'St. Lawrence County',
#  14733: 'Chautauqua County',
#  11757: 'Suffolk County',
#  12428: 'Ulster County',
#  13350: 'Herkimer County',
#  14534: 'Monroe County',
#  14543: 'Monroe County',
#  12549: 'Orange County',
#  14467: 'Monroe County',
#  14075: 'Erie County',
#  11768: 'Suffolk County',
#  10032: 'New York County',
#  10505: 'Westchester County',
#  14519: 'Wayne County',
#  10548: 'Westchester County',
#  11552: 'Nassau County',
#  14011: 'Wyoming County',
#  14843: 'Steuben County',
#  14069: 'Erie County',
#  10522: 'Westchester County',
#  14171: 'Cattaraugus County',
#  10598: 'Westchester County',
#  13039: 'Onondaga County',
#  11374: 'Queens County',
#  11361: 'Queens County',
#  10038: 'New York County',
#  14480: 'Livingston County',
#  12589: 'Ulster County',
#  14625: 'Monroe County',
#  12748: 'Sullivan County',
#  13903: 'Broome County',
#  12043: 'Schoharie County',
#  10018: 'New York County',
#  13755: 'Delaware County',
#  10583: 'Westchester County',
#  10952: 'Rockland County',
#  14614: 'Monroe County',
#  11978: 'Suffolk County',
#  14840: 'Steuben County',
#  12943: 'Essex County',
#  14468: 'Monroe County',
#  12501: 'Dutchess County',
#  11598: 'Nassau County',
#  14303: 'Niagara County',
#  13460: 'Chenango County',
#  12942: 'Essex County',
#  10962: 'Rockland County',
#  14555: 'Wayne County',
#  11430: 'Queens County',
#  10536: 'Westchester County',
#  12565: 'Columbia County',
#  11010: 'Nassau County',
#  13204: 'Onondaga County',
#  14605: 'Monroe County',
#  14043: 'Erie County',
#  13309: 'Oneida County',
#  13815: 'Chenango County',
#  12950: 'Essex County',
#  13164: 'Onondaga County',
#  14416: 'Genesee County',
#  11791: 'Nassau County',
#  11754: 'Suffolk County',
#  13037: 'Madison County',
#  12524: 'Dutchess County',
#  11239: 'Kings County',
#  12883: 'Essex County',
#  12186: 'Albany County',
#  14610: 'Monroe County',
#  13142: 'Oswego County',
#  10990: 'Orange County',
#  12472: 'Ulster County',
#  11795: 'Suffolk County',
#  12754: 'Sullivan County',
#  11209: 'Kings County',
#  12567: 'Dutchess County',
#  11780: 'Suffolk County',
#  13694: 'St. Lawrence County',
#  12932: 'Essex County',
#  11726: 'Suffolk County',
#  12972: 'Clinton County',
#  13417: 'Oneida County',
#  14427: 'Wyoming County',
#  12449: 'Ulster County',
#  13795: 'Broome County',
#  12078: 'Fulton County',
#  11931: 'Suffolk County',
#  12553: 'Orange County',
#  10460: 'Bronx County',
#  12977: 'Essex County',
#  14036: 'Genesee County',
#  14489: 'Wayne County',
#  11213: 'Kings County',
#  11958: 'Suffolk County',
#  10589: 'Westchester County',
#  14482: 'Genesee County',
#  13108: 'Onondaga County',
#  12777: 'Sullivan County',
#  10543: 'Westchester County',
#  11702: 'Suffolk County',
#  14213: 'Erie County',
#  11971: 'Suffolk County',
#  10577: 'Westchester County',
#  10541: 'Putnam County',
#  12903: 'Clinton County',
#  10105: 'New York County',
#  13159: 'Onondaga County',
#  12912: 'Clinton County',
#  12834: 'Washington County',
#  12157: 'Schoharie County',
#  13492: 'Oneida County',
#  12847: 'Hamilton County',
#  11784: 'Suffolk County',
#  11105: 'Queens County',
#  11373: 'Queens County',
#  14052: 'Erie County',
#  13667: 'St. Lawrence County',
#  12996: 'Essex County',
#  10470: 'Bronx County',
#  14094: 'Niagara County',
#  11248: 'Kings County',
#  11580: 'Nassau County',
#  13421: 'Madison County',
#  11572: 'Nassau County',
#  11944: 'Suffolk County',
#  10941: 'Orange County',
#  12165: 'Columbia County',
#  13316: 'Oneida County',
#  10549: 'Westchester County',
#  14747: 'Chautauqua County',
#  14548: 'Ontario County',
#  12106: 'Columbia County',
#  10005: 'New York County',
#  12029: 'Columbia County',
#  13695: 'St. Lawrence County',
#  10968: 'Rockland County',
#  14433: 'Wayne County',
#  12580: 'Dutchess County',
#  41076: 'Campbell County',
#  11545: 'Nassau County',
#  12184: 'Columbia County',
#  13035: 'Madison County',
#  13290: 'Onondaga County',
#  11224: 'Kings County',
#  12183: 'Albany County',
#  13408: 'Madison County',
#  11581: 'Nassau County',
#  14527: 'Yates County',
#  13830: 'Chenango County',
#  11235: 'Kings County',
#  10576: 'Westchester County',
#  14514: 'Monroe County',
#  14530: 'Wyoming County',
#  12788: 'Sullivan County',
#  11787: 'Suffolk County',
#  10468: 'Bronx County',
#  14901: 'Chemung County',
#  12480: 'Ulster County',
#  12921: 'Clinton County',
#  10006: 'New York County',
#  14040: 'Genesee County',
#  11980: 'Suffolk County',
#  11413: 'Queens County',
#  14572: 'Steuben County',
#  11762: 'Nassau County',
#  11225: 'Kings County',
#  10307: 'Richmond County',
#  12018: 'Rensselaer County',
#  13078: 'Onondaga County',
#  12870: 'Essex County',
#  11370: 'Queens County',
#  14051: 'Erie County',
#  10607: 'Westchester County',
#  13440: 'Oneida County',
#  12051: 'Greene County',
#  10992: 'Orange County',
#  12518: 'Orange County',
#  12531: 'Dutchess County',
#  13420: 'Herkimer County',
#  11550: 'Nassau County',
#  12474: 'Delaware County',
#  12188: 'Saratoga County',
#  11717: 'Suffolk County',
#  14009: 'Wyoming County',
#  14569: 'Wyoming County',
#  14059: 'Erie County',
#  11385: 'Queens County',
#  12749: 'Sullivan County',
#  11769: 'Suffolk County',
#  12742: 'Sullivan County',
#  13104: 'Onondaga County',
#  10509: 'Putnam County',
#  13041: 'Onondaga County',
#  11763: 'Suffolk County',
#  11568: 'Nassau County',
#  14437: 'Livingston County',
#  14215: 'Erie County',
#  12443: 'Ulster County',
#  11756: 'Nassau County',
#  10029: 'New York County',
#  12887: 'Washington County',
#  10512: 'Putnam County',
#  12442: 'Greene County',
#  12430: 'Delaware County',
#  12502: 'Columbia County',
#  12885: 'Warren County',
#  14422: 'Genesee County',
#  13480: 'Oneida County',
#  12776: 'Sullivan County',
#  13214: 'Onondaga County',
#  12846: 'Warren County',
#  12457: 'Ulster County',
#  10927: 'Rockland County',
#  11553: 'Nassau County',
#  13029: 'Onondaga County',
#  11948: 'Suffolk County',
#  11216: 'Kings County',
#  12406: 'Delaware County',
#  10172: 'New York County',
#  12723: 'Sullivan County',
#  14109: 'Niagara County',
#  13491: 'Herkimer County',
#  11935: 'Suffolk County',
#  11233: 'Kings County',
#  11715: 'Suffolk County',
#  11556: 'Nassau County',
#  11548: 'Nassau County',
#  12090: 'Rensselaer County',
#  10918: 'Orange County',
#  11378: 'Queens County',
#  11733: 'Suffolk County',
#  12072: 'Montgomery County',
#  13501: 'Oneida County',
#  12979: 'Clinton County',
#  14425: 'Ontario County',
#  11221: 'Kings County',
#  14895: 'Allegany County',
#  12075: 'Columbia County',
#  13790: 'Broome County',
#  10465: 'Bronx County',
#  11692: 'Queens County',
#  10603: 'Westchester County',
#  12546: 'Dutchess County',
#  12856: 'Warren County',
#  12919: 'Clinton County',
#  11417: 'Queens County'}

# %%
#mapping county information for each charger based on zipcode
Charger_df['County'] = Charger_df['ZIP'].map(zip_map) 
Charger_df.head()
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        ID                Station Name           City    ZIP           County
# 0   49941  Town of Penfield - Library       Penfield  14526    Monroe County
# 1  116756          Village of Webster        Webster  14580    Monroe County
# 2  149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983  Franklin County
# 3  157942            Houghton College       Houghton  14744  Allegany County
# 4  182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305  Richmond County

# %%
import pgeocode
zipcodes_to_search = list(Charger_df['ZIP'].unique())

nomi = pgeocode.Nominatim('us')


latitude_map = {}

for zipcode in zipcodes_to_search:
    if zipcode == 12081:
        pass
    elif zipcode == 12217:
        pass
    else:
        latitude_info = nomi.query_postal_code(str(zipcode)).latitude
        latitude_map[zipcode] = latitude_info

latitude_map

Charger_df['latitude'] = Charger_df['ZIP'].map(latitude_map) 
Charger_df
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           ID                Station Name           City    ZIP  \
# 0      49941  Town of Penfield - Library       Penfield  14526
# 1     116756          Village of Webster        Webster  14580
# 2     149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983
# 3     157942            Houghton College       Houghton  14744
# 4     182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305
# ...      ...                         ...            ...    ...
# 3079  154370       W DELAVAN DELAVAN (1)        Buffalo  14222
# 3080  168146       HAMPTON INN STATION 1  Staten Island  10314
# 3081  183460    SRYMCASSB BATTENKILL 1.1      Greenwich  12834
# 3082  152393  PAUL MILLER VW VW_408107_A           Rome  13440
# 3083  224227        GENESEO E PARK RIGHT        Geneseo  14454
#
#                  County  latitude
# 0         Monroe County   43.1396
# 1         Monroe County   43.2196
# 2       Franklin County   44.3243
# 3       Allegany County   42.4228
# 4       Richmond County   40.5973
# ...                 ...       ...
# 3079        Erie County   42.9164
# 3080    Richmond County   40.6039
# 3081  Washington County   43.0947
# 3082      Oneida County   43.2193
# 3083  Livingston County   42.7938
#
# [3084 rows x 6 columns]

# %%
zipcodes_to_search = list(Charger_df['ZIP'].unique())

nomi = pgeocode.Nominatim('us')

longitude_map = {}

for zipcode in zipcodes_to_search:
    if zipcode == 12081:
        pass
    elif zipcode == 12217:
        pass
    else:
        longitude_info = nomi.query_postal_code(str(zipcode)).longitude
        longitude_map[zipcode] = longitude_info

longitude_map

Charger_df['longitude'] = Charger_df['ZIP'].map(longitude_map) 
Charger_df
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           ID                Station Name           City    ZIP  \
# 0      49941  Town of Penfield - Library       Penfield  14526
# 1     116756          Village of Webster        Webster  14580
# 2     149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983
# 3     157942            Houghton College       Houghton  14744
# 4     182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305
# ...      ...                         ...            ...    ...
# 3079  154370       W DELAVAN DELAVAN (1)        Buffalo  14222
# 3080  168146       HAMPTON INN STATION 1  Staten Island  10314
# 3081  183460    SRYMCASSB BATTENKILL 1.1      Greenwich  12834
# 3082  152393  PAUL MILLER VW VW_408107_A           Rome  13440
# 3083  224227        GENESEO E PARK RIGHT        Geneseo  14454
#
#                  County  latitude  longitude
# 0         Monroe County   43.1396   -77.4560
# 1         Monroe County   43.2196   -77.4616
# 2       Franklin County   44.3243   -74.1330
# 3       Allegany County   42.4228   -78.2063
# 4       Richmond County   40.5973   -74.0768
# ...                 ...       ...        ...
# 3079        Erie County   42.9164   -78.8763
# 3080    Richmond County   40.6039   -74.1472
# 3081  Washington County   43.0947   -73.5030
# 3082      Oneida County   43.2193   -75.4498
# 3083  Livingston County   42.7938   -77.7996
#
# [3084 rows x 7 columns]

# %%
Charger_df['median_home_value'] = Charger_df['ZIP'].map(median_home_value_map) 
Charger_df
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           ID                Station Name           City    ZIP  \
# 0      49941  Town of Penfield - Library       Penfield  14526
# 1     116756          Village of Webster        Webster  14580
# 2     149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983
# 3     157942            Houghton College       Houghton  14744
# 4     182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305
# ...      ...                         ...            ...    ...
# 3079  154370       W DELAVAN DELAVAN (1)        Buffalo  14222
# 3080  168146       HAMPTON INN STATION 1  Staten Island  10314
# 3081  183460    SRYMCASSB BATTENKILL 1.1      Greenwich  12834
# 3082  152393  PAUL MILLER VW VW_408107_A           Rome  13440
# 3083  224227        GENESEO E PARK RIGHT        Geneseo  14454
#
#                  County  latitude  longitude  population_density  \
# 0         Monroe County   43.1396   -77.4560              1184.0
# 1         Monroe County   43.2196   -77.4616              1188.0
# 2       Franklin County   44.3243   -74.1330                36.0
# 3       Allegany County   42.4228   -78.2063               120.0
# 4       Richmond County   40.5973   -74.0768              9819.0
# ...                 ...       ...        ...                 ...
# 3079        Erie County   42.9164   -78.8763             10937.0
# 3080    Richmond County   40.6039   -74.1472              6235.0
# 3081  Washington County   43.0947   -73.5030                76.0
# 3082      Oneida County   43.2193   -75.4498               381.0
# 3083  Livingston County   42.7938   -77.7996               219.0
#
#       median_home_value  occupied_housing_units
# 0              169000.0                  8012.0
# 1              179100.0                 20116.0
# 2              162400.0                  3524.0
# 3              105500.0                   378.0
# 4              415300.0                 15145.0
# ...                 ...                     ...
# 3079           228700.0                  7074.0
# 3080           437500.0                 30709.0
# 3081           179500.0                  2634.0
# 3082            97000.0                 17161.0
# 3083           160800.0                  3247.0
#
# [3084 rows x 10 columns]

# %%
#Creating a dictionary that shows which latitude each zipcode is in
zipcodes_to_search = list(Charger_df['ZIP'].unique())
search = SearchEngine()
median_household_income_map = {}

# excluding the zipcode not corresponded to any county
for zipcode in zipcodes_to_search:
    if zipcode == 12081:
        pass
    elif zipcode == 12217:
        pass
    else:
        median_household_income_info = search.by_zipcode(zipcode).median_household_income
        median_household_income_map[zipcode] = median_household_income_info

median_home_value_map

Charger_df['median_household_income'] = Charger_df['ZIP'].map(median_household_income_map) 
Charger_df
# Out:
# /Users/hosseindabiri/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           ID                Station Name           City    ZIP  \
# 0      49941  Town of Penfield - Library       Penfield  14526
# 1     116756          Village of Webster        Webster  14580
# 2     149787   HOTSARA CHARGER STATION 1   Saranac Lake  12983
# 3     157942            Houghton College       Houghton  14744
# 4     182295    NYC FLEET DPRMBLOT8_1_L3  Midland Beach  10305
# ...      ...                         ...            ...    ...
# 3079  154370       W DELAVAN DELAVAN (1)        Buffalo  14222
# 3080  168146       HAMPTON INN STATION 1  Staten Island  10314
# 3081  183460    SRYMCASSB BATTENKILL 1.1      Greenwich  12834
# 3082  152393  PAUL MILLER VW VW_408107_A           Rome  13440
# 3083  224227        GENESEO E PARK RIGHT        Geneseo  14454
#
#                  County  latitude  longitude  population_density  \
# 0         Monroe County   43.1396   -77.4560              1184.0
# 1         Monroe County   43.2196   -77.4616              1188.0
# 2       Franklin County   44.3243   -74.1330                36.0
# 3       Allegany County   42.4228   -78.2063               120.0
# 4       Richmond County   40.5973   -74.0768              9819.0
# ...                 ...       ...        ...                 ...
# 3079        Erie County   42.9164   -78.8763             10937.0
# 3080    Richmond County   40.6039   -74.1472              6235.0
# 3081  Washington County   43.0947   -73.5030                76.0
# 3082      Oneida County   43.2193   -75.4498               381.0
# 3083  Livingston County   42.7938   -77.7996               219.0
#
#       median_home_value  occupied_housing_units  median_household_income
# 0              169000.0                  8012.0                  77386.0
# 1              179100.0                 20116.0                  69189.0
# 2              162400.0                  3524.0                  47329.0
# 3              105500.0                   378.0                  50298.0
# 4              415300.0                 15145.0                  70758.0
# ...                 ...                     ...                      ...
# 3079           228700.0                  7074.0                  52073.0
# 3080           437500.0                 30709.0                  77242.0
# 3081           179500.0                  2634.0                  60913.0
# 3082            97000.0                 17161.0                  49755.0
# 3083           160800.0                  3247.0                  51625.0
#
# [3084 rows x 11 columns]

# %%
# Exporting the DataFrame as WeatherPy_Database.csv into the Weather_Database folder
# defining the path
output_data_path = "Resources/Demographic_Database.csv"

# exporting data into csv file
Charger_df.to_csv(output_data_path, index_label="city_id")

# %%
lats = list(Charger_df['latitude'])
lngs = list(Charger_df['longitude'])

# pack the random coordinates into a zip
coordinates_list = zip(lats,lngs)

coordinates_list

# %%
coordinates= list(coordinates_list)
print(coordinates)
# Out:
# [(43.1396, -77.456), (43.2196, -77.4616), (44.3243, -74.133), (42.4228, -78.2063), (40.5973, -74.0768), (42.8853, -78.7462), (40.6412, -74.0133), (43.1528, -76.2235), (41.0977, -74.0109), (42.4474, -76.4837), (40.7294, -73.6828), (42.7198, -73.8207), (40.9209, -72.3491), (41.595, -73.8876), (40.6625, -73.9145), (42.247, -73.7552), (42.884, -78.8597), (41.1177, -74.1241), (42.7287, -73.6683), (40.7651, -73.9638), (43.162, -76.3237), (43.1834, -77.6043), (41.0459, -71.944), (42.247, -73.7552), (40.6729, -73.5365), (42.7462, -73.763), (40.9262, -72.652), (43.005, -73.8486), (42.0738, -73.9797), (43.2264, -75.4083), (42.6359, -73.7219), (42.9731, -78.845), (44.3243, -74.133), (42.4406, -76.4966), (43.2346, -77.6577), (42.6158, -73.8373), (42.4228, -78.2063), (43.0708, -73.7408), (42.2959, -78.6606), (43.0708, -73.7408), (40.7571, -73.9657), (43.0183, -78.9591), (42.8499, -73.7851), (40.9271, -73.0127), (42.7005, -74.9243), (41.7464, -74.1092), (40.7444, -73.0542), (42.7003, -73.8575), (40.7975, -73.9683), (40.7069, -73.8297), (42.6847, -73.7354), (42.8614, -78.8205), (40.6039, -74.1472), (40.7763, -73.9529), (41.0572, -73.8136), (40.7185, -74.0025), (42.1383, -77.0475), (42.6413, -73.7641), (40.8472, -73.5349), (42.713, -73.7739), (42.8499, -73.7851), (40.778, -73.9884), (42.4406, -76.4966), (42.9866, -77.418), (41.0222, -73.6798), (40.8496, -73.9356), (43.0654, -75.2906), (43.6451, -73.8066), (43.0834, -77.6344), (44.445, -74.2664), (42.7198, -73.8207), (42.8499, -73.7851), (43.2203, -77.5994), (41.747, -73.8143), (43.2566, -77.6652), (42.713, -73.7739), (41.0977, -74.0109), (43.0474, -74.8606), (40.7443, -73.9781), (42.8614, -78.8205), (40.6637, -73.638), (43.6441, -75.4132), (40.8015, -72.8676), (43.0892, -77.436), (42.9695, -77.5781), (40.7105, -74.0163), (40.7571, -73.9657), (42.6726, -76.1878), (40.6316, -74.0927), (44.3243, -74.133), (42.0821, -78.426), (42.9685, -78.7492), (43.6978, -73.986), (40.7143, -74.006), (42.7003, -73.8575), (44.2796, -73.982), (40.6536, -73.5866), (42.6413, -73.7641), (43.0878, -75.7602), (42.1805, -76.8345), (43.2203, -77.5994), (41.7351, -73.587), (43.2203, -77.5994), (43.0708, -73.7408), (43.2126, -77.704), (42.8939, -78.8681), (40.7139, -74.007), (41.6576, -74.1672), (40.6505, -73.9349), (43.1577, -77.608), (43.041, -76.1489), (42.7287, -73.6683), (42.8614, -78.8205), (41.135, -73.7845), (40.7651, -73.9638), (42.7003, -73.8575), (40.5905, -73.5808), (40.7975, -73.9683), (42.9499, -78.8599), (40.6521, -74.0018), (40.7513, -73.883), (40.7597, -73.9918), (42.7063, -74.0193), (43.0651, -76.4598), (42.7462, -73.763), (42.7198, -73.8207), (44.8482, -74.2928), (42.7298, -73.7123), (42.7823, -73.9448), (42.7063, -74.0193), (43.0069, -74.3715), (43.1577, -77.608), (41.7803, -73.6885), (42.7003, -73.8575), (42.3437, -76.8396), (41.1609, -74.0608), (42.8161, -73.9398), (42.9082, -78.8225), (42.8135, -77.6635), (42.7823, -74.7444), (41.3946, -74.3302), (42.7287, -73.6683), (41.0256, -73.9229), (40.6969, -73.7877), (43.005, -73.8486), (41.1472, -73.9962), (42.4877, -79.3283), (40.8904, -73.8503), (40.6336, -73.996), (42.93, -76.5626), (43.1685, -77.6845), (40.7685, -73.9588), (42.6413, -73.7641), (43.0708, -73.7408), (42.7462, -73.763), (43.0654, -75.2906), (42.9255, -78.7481), (40.7764, -73.9827), (42.4474, -76.4837), (43.4394, -76.4613), (44.6927, -73.466), (40.6669, -73.9828), (41.7035, -73.9117), (42.4333, -79.3339), (40.694, -73.9903), (44.9825, -74.6626), (40.7618, -73.9505), (42.4406, -76.4966), (43.0834, -77.6344), (43.0607, -76.1369), (40.685, -73.5103), (42.8179, -73.9206), (43.1528, -76.2235), (42.7287, -73.6683), (40.7597, -73.9918), (43.329, -73.6818), (42.713, -73.7739), (43.041, -76.1489), (42.1219, -73.8625), (43.2662, -74.2288), (43.0354, -76.1282), (40.7685, -73.9588), (43.1116, -75.2756), (40.8798, -73.9067), (41.7953, -73.9809), (40.5682, -74.1184), (40.7557, -73.5723), (42.6417, -73.7854), (40.6205, -73.7474), (41.3005, -74.1249), (40.7597, -73.9918), (42.7298, -73.7123), (41.1673, -73 ...

# %%
# Get the nearest city using the citipy module
# Create a list to hold the nearest cities
nearest_cities=[]

# detrmining the nearest city for each pair of lats and lngs
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#including unique city in the list
    if city not in nearest_cities:
        nearest_cities.append(city)
#printing the city count to see how many cities we have in the list

len(nearest_cities)
# Out:
# 170

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# indicating the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(nearest_cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(55)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_info = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_info["coord"]["lat"]
        city_lng = city_info["coord"]["lon"]
        city_country = city_info["sys"]["country"]
        city_max_temp = city_info["main"]["temp_max"]
        city_min_temp = city_info["main"]["temp_min"]
        city_humidity = city_info["main"]["humidity"]
        city_clouds = city_info["clouds"]["all"]
        city_wind = city_info["wind"]["speed"]
        description = city_info['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_info["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Min Temp": city_min_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | brighton
# Processing Record 2 of Set 1 | huntingdon
# Processing Record 3 of Set 1 | olean
# Processing Record 4 of Set 1 | bayonne
# Processing Record 5 of Set 1 | cheektowaga
# Processing Record 6 of Set 1 | new york
# Processing Record 7 of Set 1 | fairmount
# Processing Record 8 of Set 1 | nanuet
# Processing Record 9 of Set 1 | ithaca
# Processing Record 10 of Set 1 | new hyde park
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | old saybrook
# Processing Record 13 of Set 1 | arlington
# Processing Record 14 of Set 1 | kingston
# Processing Record 15 of Set 1 | buffalo
# Processing Record 16 of Set 1 | suffern
# Processing Record 17 of Set 1 | troy
# Processing Record 18 of Set 1 | guttenberg
# Processing Record 19 of Set 1 | rochester
# Processing Record 20 of Set 1 | groton
# Processing Record 21 of Set 1 | bellmore
# Processing Record 22 of Set 1 | watervliet
# Processing Record 23 of Set 1 | mastic
# Processing Record 24 of Set 1 | saratoga springs
# Processing Record 25 of Set 1 | rome
# Processing Record 26 of Set 1 | kenmore
# Processing Record 27 of Set 1 | greece
# Processing Record 28 of Set 1 | tonawanda
# Processing Record 29 of Set 1 | cohoes
# Processing Record 30 of Set 1 | terryville
# Processing Record 31 of Set 1 | oneonta
# Processing Record 32 of Set 1 | poughkeepsie
# Processing Record 33 of Set 1 | sayville
# Processing Record 34 of Set 1 | edgewater
# Processing Record 35 of Set 1 | elmont
# Processing Record 36 of Set 1 | west seneca
# Processing Record 37 of Set 1 | hartsdale
# Processing Record 38 of Set 1 | corning
# Processing Record 39 of Set 1 | syosset
# Processing Record 40 of Set 1 | canandaigua
# Processing Record 41 of Set 1 | rye brook
# Processing Record 42 of Set 1 | fort lee
# Processing Record 43 of Set 1 | utica
# Processing Record 44 of Set 1 | glens falls
# Processing Record 45 of Set 1 | irondequoit
# Processing Record 46 of Set 1 | oceanside
# Processing Record 47 of Set 1 | shirley
# Processing Record 48 of Set 1 | cortland
# Processing Record 49 of Set 1 | plattsburgh
# Processing Record 50 of Set 1 | freeport
# Processing Record 1 of Set 2 | oneida
# Processing Record 2 of Set 2 | elmira
# Processing Record 3 of Set 2 | new milford
# Processing Record 4 of Set 2 | newburgh
# Processing Record 5 of Set 2 | syracuse
# Processing Record 6 of Set 2 | ossining
# Processing Record 7 of Set 2 | weehawken
# Processing Record 8 of Set 2 | rotterdam
# Processing Record 9 of Set 2 | auburn
# Processing Record 10 of Set 2 | gloversville
# Processing Record 11 of Set 2 | monsey
# Processing Record 12 of Set 2 | schenectady
# Processing Record 13 of Set 2 | middletown
# Processing Record 14 of Set 2 | dobbs ferry
# Processing Record 15 of Set 2 | new city
# Processing Record 16 of Set 2 | dunkirk
# Processing Record 17 of Set 2 | eastchester
# Processing Record 18 of Set 2 | oswego
# Processing Record 19 of Set 2 | fredonia
# Processing Record 20 of Set 2 | cornwall
# Processing Record 21 of Set 2 | wantagh
# Processing Record 22 of Set 2 | yonkers
# Processing Record 23 of Set 2 | new cassel
# Processing Record 24 of Set 2 | woodmere
# Processing Record 25 of Set 2 | kiryas joel
# Processing Record 26 of Set 2 | port jervis
# Processing Record 27 of Set 2 | watertown
# Processing Record 28 of Set 2 | ridge
# Processing Record 29 of Set 2 | deer park
# Processing Record 30 of Set 2 | hamburg
# Processing Record 31 of Set 2 | massapequa park
# Processing Record 32 of Set 2 | pittsfield
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | batavia
# Processing Record 35 of Set 2 | endicott
# Processing Record 36 of Set 2 | white plains
# Processing Record 37 of Set 2 | peekskill
# Processing Record 38 of Set 2 | farmingville
# Processing Record 39 of Set 2 | binghamton
# Processing Record 40 of Set 2 | north tonawanda
# Processing Record 41 of Set 2 | plainview
# Processing Record 42 of Set 2 | sleepy hollow
# Processing Record 43 of Set 2 | amsterdam
# Processing Record 44 of Set 2 | potsdam
# Processing Record 45 of Set 2 | mount vernon
# Processing Record 46 of Set 2 | stony brook
# Processing Record 47 of Set 2 | garden city
# Processing Record 48 of Set 2 | lake grove
# Processing Record 49 of Set 2 | south farmingdale
# Processing Record 50 of Set 2 | new rochelle
# Processing Record 1 of Set 3 | rye
# Processing Record 2 of Set 3 | geneva
# Processing Record 3 of Set 3 | mamaroneck
# Processing Record 4 of Set 3 | endwell
# Processing Record 5 of Set 3 | lancaster
# Processing Record 6 of Set 3 | shelburne
# Processing Record 7 of Set 3 | beacon
# Processing Record 8 of Set 3 | niagara falls
# Processing Record 9 of Set 3 | massena
# Processing Record 10 of Set 3 | mount kisco
# Processing Record 11 of Set 3 | amityville
# Processing Record 12 of Set 3 | andorra la vella
# Processing Record 13 of Set 3 | east patchogue
# Processing Record 14 of Set 3 | great neck
# Processing Record 15 of Set 3 | bay shore
# Processing Record 16 of Set 3 | newark
# Processing Record 17 of Set 3 | hauppauge
# Processing Record 18 of Set 3 | centereach
# Processing Record 19 of Set 3 | dix hills
# Processing Record 20 of Set 3 | hicksville
# Processing Record 21 of Set 3 | huntington station
# Processing Record 22 of Set 3 | westbury
# Processing Record 23 of Set 3 | north babylon
# Processing Record 24 of Set 3 | east meadow
# Processing Record 25 of Set 3 | pearl river
# Processing Record 26 of Set 3 | fulton
# Processing Record 27 of Set 3 | bradford
# Processing Record 28 of Set 3 | mineola
# Processing Record 29 of Set 3 | huntington
# Processing Record 30 of Set 3 | melville
# Processing Record 31 of Set 3 | carteret
# Processing Record 32 of Set 3 | commack
# Processing Record 33 of Set 3 | nesconset
# Processing Record 34 of Set 3 | middlebury
# Processing Record 35 of Set 3 | bethpage
# Processing Record 36 of Set 3 | glen cove
# Processing Record 37 of Set 3 | lindenhurst
# Processing Record 38 of Set 3 | east northport
# Processing Record 39 of Set 3 | west hempstead
# Processing Record 40 of Set 3 | scarsdale
# Processing Record 41 of Set 3 | franklin square
# Processing Record 42 of Set 3 | depew
# Processing Record 43 of Set 3 | kings park
# Processing Record 44 of Set 3 | west milford
# Processing Record 45 of Set 3 | west islip
# Processing Record 46 of Set 3 | saint james
# Processing Record 47 of Set 3 | morrisburg
# Processing Record 48 of Set 3 | copiague
# Processing Record 49 of Set 3 | clinton
# Processing Record 50 of Set 3 | babylon
# Processing Record 1 of Set 4 | selden
# Processing Record 2 of Set 4 | lockport
# Processing Record 3 of Set 4 | valley stream
# Processing Record 4 of Set 4 | fort thomas
# Processing Record 5 of Set 4 | smithtown
# Processing Record 6 of Set 4 | east massapequa
# Processing Record 7 of Set 4 | perth amboy
# Processing Record 8 of Set 4 | danbury
# Processing Record 9 of Set 4 | hempstead
# Processing Record 10 of Set 4 | brentwood
# Processing Record 11 of Set 4 | bohemia
# Processing Record 12 of Set 4 | medford
# Processing Record 13 of Set 4 | levittown
# Processing Record 14 of Set 4 | haverstraw
# Processing Record 15 of Set 4 | uniondale
# Processing Record 16 of Set 4 | carbondale
# Processing Record 17 of Set 4 | patchogue
# Processing Record 18 of Set 4 | bennington
# Processing Record 19 of Set 4 | lacolle
# Processing Record 20 of Set 4 | johnson city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len (city_data)
# Out:
# 170

# %%
# adding  the weather data to a new DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat      Lng  Max Temp  Min Temp  Humidity  \
# 0     Brighton      GB  50.8284  -0.1395     48.79     44.10        82
# 1   Huntingdon      GB  52.3305  -0.1865     44.80     41.86        84
# 2        Olean      US  42.0776 -78.4297     24.96     21.54        79
# 3      Bayonne      FR  43.3333  -1.4167     55.13     52.75        94
# 4  Cheektowaga      US  42.9034 -78.7548     27.16     23.94        56
#
#    Cloudiness  Wind Speed Current Description
# 0           7        7.00           clear sky
# 1         100       12.12     overcast clouds
# 2         100        8.05          light snow
# 3          75        4.61       broken clouds
# 4          20       20.71          few clouds

# %%
# Exporting the DataFrame as WeatherPy_Database.csv into the Weather_Database folder
# defining the path
output_data_path = "Resources/WeatherPy_Database.csv"

# exporting data into csv file
city_data_df.to_csv(output_data_path, index_label="city_id")
